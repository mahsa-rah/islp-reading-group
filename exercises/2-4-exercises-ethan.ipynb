# %% [markdown]
# # 2.4 Exercises (Ethan)

# %% [markdown]
# ## Conceptual

# %% [markdown]
# ### 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# #### a. The sample size $n$ is extremely large, and the number of predictors $p$ is small.

# %% [markdown]
# An inflexible method may do better to avoid overfitting, but this depends on the observed relationship between the features and target.

# %% [markdown]
# #### b. The number of predictors $p$ is extremely large, and the number of observations $n$ is small.

# %% [markdown]
# An inflexible learning method will work better to reduce the number of predictors included (via methods such as regularization).

# %% [markdown]
# #### c. The relationship between the predictors and response is highly non-linear.

# %% [markdown]
# A flexible statistical learning method will better capture nonlinear relationships.

# %% [markdown]
# #### d. The variance of the error terms, i.e. $\sigma^2 = Var(\epsilon)$, is extremely high.

# %% [markdown]
# A flexible learning method will work better as high variance of error terms suggests a nonlinear relationship.

# %% [markdown]
# ### 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide $n$ and $p$.

# %% [markdown]
# #### a. We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.

# %% [markdown]
# This is a regression problem with the goal of inference; $n=500$, $p=3$.

# %% [markdown]
# #### b. We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.

# %% [markdown]
# This is a (binary) classification problem with the goal of prediction; $n = 20$, $p = 13$.

# %% [markdown]
# #### c. We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.

# %% [markdown]
# This is a regression problem with the goal of prediction: $n = 52$, $p = 3$.

# %% [markdown]
# ### 3. We now revisit the bias-variance decomposition.

# %% [markdown]
# #### a. Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one.

# %% [markdown]
# <div align="center">
#   <img src="bias_variance.png" alt="Bias-Variance Tradeoff" width="500">
# </div>

# %% [markdown]
# #### b. Explain why each of the five curves has the shape displayed in part (a).

# %% [markdown]
# <div style="margin-left: 20px;">
#     <ol type="i">
#         <li>Squared bias gradually decreases as model flexibility increases (the results depends less on the choice of model).</li>
#         <li>Variance increases as flexibility increases (the result depends more on the training data).</li>
#         <li>The training error will always decrease as the model flexbility increases (but this may be overfitting).</li>
#         <li>The test error has a (concave up) curve pattern with respect to flexibility, with the vertex indicating the point where it starts overfitting.</li>
#         <li>Bayes (Irreducible Error) is inherently immutable so is represented as a horizontal line.</li>
#     </ol>
# </div>

# %% [markdown]
# ### 4. You will now think of some real-life applications for statistical learning.

# %% [markdown]
# #### a. Describe three real-life applications in which classification might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.

# %% [markdown]
# <div style="margin-left: 20px;">
#     <ol type="i">
#         <li> For businesses, classifying whether users will buy a product (yes/no = <i>target</i>) based on their user behavior (<i>features</i>). This is a <i>prediction</i> task. </li>
#         <li> For medical applications, classifying a tumor as benign or malignant (<i>target</i>) based on an image (<i>features</i>). This is a <i>prediction</i> task. </li>
#         <li> Classifying a dog breed (<i>target</i>) based on a picture (<i>features</i>). This is a <i>prediction</i> task.</li>
#     </ol>
# </div>

# %% [markdown]
# #### b. Describe three real-life applications in which regression might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.

# %% [markdown]
# <div style="margin-left: 20px;">
#     <ol type="i">
#         <li> Predicting value of bitcoin (<i>target</i>) based on previous values (<i>features</i>). This is a <i>prediction</i> task. </li>
#         <li> Predicting the probability of a next word in a sentence (<i>target</i>) based on previous words in the sentence (<i>features</i>). This is a <i>prediction</i> task. </li>
#         <li> Predicting rent  (<i>target</i>) in a neighborhood based on economic data(<i>features</i>). This is a <i>inference</i> task.</li>
#     </ol>
# </div>

# %% [markdown]
# #### c. Describe three real-life applications in which cluster analysis might be useful.

# %% [markdown]
# <div style="margin-left: 20px;">
#     <ol type="i">
#         <li> Clustering songs into genres based on sonic data. </li>
#         <li> Clustering conceptual topics from a large body of text data. </li>
#         <li> Cl</li>
#     </ol>
# </div>
